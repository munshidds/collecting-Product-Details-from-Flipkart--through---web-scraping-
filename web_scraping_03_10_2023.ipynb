# %% [markdown]
# <a href="https://colab.research.google.com/github/munshidds/collecting-mobile-informations-from-flipkart-through---web-scraping-/blob/main/web_scraping_03_10_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Web Scraping**
#  Product Details on Flipkart**
#
# In the world of e-commerce, staying updated with the latest product information, prices, and customer reviews is crucial for both consumers and businesses. However, manually collecting this data from online platforms can be a time-consuming and tedious process. This is where web scraping comes into play.
#
# **Web scraping** is the process of programmatically extracting data from websites. In this specific task, we aim to scrape product details of iPhones listed on **Flipkart**, one of India's leading e-commerce platforms. Flipkart provides an extensive collection of iPhone products, each with its own set of attributes such as name, price, ratings, and specifications.
#
# **Beautiful Soup** is a Python library that simplifies the parsing and extraction of data from HTML and XML documents. It allows us to navigate the HTML structure of a webpage, locate specific elements, and extract the information we need.
#
# **The main objectives of this web scraping task are:**
#
# 1. **Data Collection:** Using BeautifulSoup, we will send HTTP GET requests to Flipkart's iPhone product pages and retrieve the HTML content.
#
# 2. **Data Extraction:** We will parse the HTML content to locate and extract relevant data, such as product names, prices, ratings, and specifications.
#
# 3. **Data Storage:** The extracted data will be stored in an organized format, such as a Pandas DataFrame or a CSV file, for further analysis or reporting.
#
# 4. **Automation:** By automating this data collection process, we can periodically update our dataset to ensure it reflects the latest product offerings and prices on Flipkart.

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as req

# %%
url_f='https://www.flipkart.com/search?q=i%20phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
uclient=req(url_f)
page_html=uclient.read()
# page_html

# %%
uclient.close()

# %%
page_soup=soup(page_html,'html.parser')
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers=page_soup.find_all('div',{'class':'_4rR01T'})
containers
# Out:
# [<div class="_4rR01T">APPLE iPhone 13 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Pink, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (Black, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 12 (Blue, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 12 (White, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Green, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (Black, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 12 (White, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 12 (Green, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (White, 128 GB)</div>,
# ...

# %%
containers
extracted_text=[]
for i in containers:
  text=str(i).find('APPLE')
  end_text=str(i).find(')')
  extracted_text.append(str(i)[text:end_text].split('(')[0]+','+str(i)[text:end_text].split('(')[1])

len(extracted_text)
extracted_text
# Out:
# ['APPLE iPhone 13 ,Blue, 128 GB',
#  'APPLE iPhone 13 ,Midnight, 128 GB',
#  'APPLE iPhone 13 ,Pink, 128 GB',
#  'APPLE iPhone 13 ,Starlight, 128 GB',
#  'APPLE iPhone 14 ,Blue, 128 GB',
#  'APPLE iPhone 11 ,Black, 64 GB',
#  'APPLE iPhone 12 ,Blue, 64 GB',
#  'APPLE iPhone 12 ,White, 64 GB',
#  'APPLE iPhone 14 ,Starlight, 128 GB',
#  'APPLE iPhone 14 ,Midnight, 128 GB',
#  'APPLE iPhone 13 ,Green, 128 GB',
#  'APPLE iPhone 11 ,Black, 128 GB',
#  'APPLE iPhone 12 ,White, 128 GB',
#  'APPLE iPhone 12 ,Green, 128 GB',
#  'APPLE iPhone 11 ,White, 128 GB',
#  'APPLE iPhone 14 ,Purple, 128 GB',
#  'APPLE iPhone 14 Plus ,Blue, 128 GB',
#  'APPLE iPhone 13 ,Midnight, 256 GB',
#  'APPLE iPhone 13 ,Starlight, 256 GB',
#  'APPLE iPhone 13 ,Green, 256 GB',
#  'APPLE iPhone 13 ,Blue, 256 GB',
#  'APPLE iPhone 12 ,Purple, 128 GB',
#  'APPLE iPhone 12 ,Purple, 64 GB',
#  'APPLE iPhone 12 ,Black, 64 GB']

# %%
price_container=page_soup.find_all('div',{"class":"_30jeq3 _1_WHN1"})
# price_container
price_container[0].text
# Out:
# '₹52,499'

# %%
price=[]
for i in price_container:
  price.append(i.text)

# price

# %%
with open("iphone_data.csv",'w') as iphone_file:
  iphone_file.write('Phone model,Colur,Storage,Rate\n')
  for i,j in zip(extracted_text,price):
    iphone_file.write(str(i)+",")
    iphone_file.write(str(j).replace(',','')+'\n')

# %%
import pandas as pd
data=pd.read_csv('iphone_data.csv')
# data
# Out:
#               Phone model      Colur  Storage    Rate
# 0        APPLE iPhone 13        Blue   128 GB  ₹52499
# 1        APPLE iPhone 13    Midnight   128 GB  ₹52499
# 2        APPLE iPhone 13        Pink   128 GB  ₹52499
# 3        APPLE iPhone 13   Starlight   128 GB  ₹52499
# 4        APPLE iPhone 14        Blue   128 GB  ₹64999
# 5        APPLE iPhone 11       Black    64 GB  ₹36999
# 6        APPLE iPhone 12        Blue    64 GB  ₹48999
# 7        APPLE iPhone 12       White    64 GB  ₹48999
# 8        APPLE iPhone 14   Starlight   128 GB  ₹64999
# 9        APPLE iPhone 14    Midnight   128 GB  ₹64999
# 10       APPLE iPhone 13       Green   128 GB  ₹52499
# 11       APPLE iPhone 11       Black   128 GB  ₹51999
# 12       APPLE iPhone 12       White   128 GB  ₹51999
# 13       APPLE iPhone 12       Green   128 GB  ₹73999
# 14       APPLE iPhone 11       White   128 GB  ₹64999
# 15       APPLE iPhone 14      Purple   128 GB  ₹39999
# ...

# %%
data.to_csv('iphone_data_with_price.csv',index=False)

# %%
pd.read_csv('iphone_data_with_price.csv').head(10)
# Out:
#         Phone model       Colur  Storage    Rate
# 0  APPLE iPhone 13          NaN   128 GB  ₹52499
# 1  APPLE iPhone 13    0Midnight   128 GB  ₹52499
# 2  APPLE iPhone 13        0Pink   128 GB  ₹52499
# 3  APPLE iPhone 13   0Starlight   128 GB  ₹52499
# 4  APPLE iPhone 14        0Blue   128 GB  ₹64999
# 5  APPLE iPhone 11       0Black    64 GB  ₹36999
# 6  APPLE iPhone 12       0White    64 GB  ₹48999
# 7  APPLE iPhone 12        0Blue    64 GB  ₹48999
# 8  APPLE iPhone 14   0Starlight   128 GB  ₹64999
# 9  APPLE iPhone 14    0Midnight   128 GB  ₹64999

# %%
import pickle

file_name = 'iphone_data_final.pkl'

with open(file_name, 'wb') as file:
    pickle.dump(data, file)

print(f'DataFrame saved to {file_name}')
# Out:
# DataFrame saved to iphone_data_final.pkl

# %% [markdown]
# access tables from url

# %%
import pandas as pd
tables_from_url=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_India')
tables_from_url[1].head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 371.9                        532.0
# 1  1981                 431.5                        603.2
# 2  1982                 474.1                        647.5
# 3  1983                 528.6                        705.3
# 4  1984                 568.6                        741.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     189.4                            271.0
# 1                     196.5                            274.7
# 2                     203.5                            278.0
# 3                     222.0                            296.3
# 4                     215.6                            281.1
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              5.3%                       11.3%                       NaN
# 1              6.0%                       12.7%                       NaN
# ...
